# %%
import pandas as pd

parquet_file = 'openfda.parquet'

df_main = pd.read_parquet(parquet_file)

df_main.head()
# Out:
#   application_number       sponsor_name openfda_application_number_x  \
# 0          NDA017391  CASPER PHARMA LLC                         None
# 1          NDA017391  CASPER PHARMA LLC                         None
# 2          NDA017391  CASPER PHARMA LLC                         None
# 3          NDA017391  CASPER PHARMA LLC                         None
# 4          NDA017391  CASPER PHARMA LLC                         None
#
#   openfda_brand_name_x openfda_generic_name_x openfda_manufacturer_name_x  \
# 0                 None                   None                        None
# 1                 None                   None                        None
# 2                 None                   None                        None
# 3                 None                   None                        None
# 4                 None                   None                        None
#
#   openfda_product_ndc_x openfda_product_type_x openfda_route_x  \
# ...
